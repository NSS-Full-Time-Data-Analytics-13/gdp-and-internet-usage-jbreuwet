# %%
GDP AND INTERNET USE PROJECT

# %% [markdown]
# #3------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #4------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2021  1517.016266              NaN
# 1     Afghanistan  2020  1968.341002              NaN
# 2     Afghanistan  2019  2079.921861              NaN
# 3     Afghanistan  2018  2060.698973              NaN
# 4     Afghanistan  2017  2096.093111              NaN

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  7662 non-null   object
#  1   Year             7662 non-null   int64
#  2   Value            7662 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 239.6+ KB

# %% [markdown]
# #5----------------------------------------------------------------------------------------------------------------------------------------
# There are 7662 rows and 3 columns in gdp_df with columns listed as Country or Area (object), Year (integer), Value (float), and Value Footnotes (float)

# %% [markdown]
# #6----------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])

# %%
gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']

# %% [markdown]
# #7------------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_df.Year.value_counts()
# Out:
# Year
# 2013    242
# 2016    242
# 2014    242
# 2015    242
# 2020    242
# 2017    242
# 2018    242
# 2019    242
# 2021    241
# 2012    240
# 2011    240
# 2010    239
# 2009    239
# 2008    238
# 2007    237
# 2006    237
# 2004    236
# 2005    236
# 2003    235
# 2002    235
# 2001    234
# 2000    233
# 2022    232
# 1999    227
# 1998    226
# 1997    226
# 1996    223
# 1995    223
# 1994    213
# 1993    211
# 1992    210
# 1991    208
# 1990    207
# Name: count, dtype: int64

# %%
year_count = gdp_df.Country.value_counts()

# %%
year_count = year_count.to_frame()
year_count
# Out:
#                                               count
# Country
# Least developed countries: UN classification     33
# Middle East & North Africa                       33
# Middle East & North Africa (IDA & IBRD)          33
# Middle income                                    33
# Mongolia                                         33
# ...                                             ...
# Kosovo                                           15
# Sint Maarten (Dutch part)                        14
# Turks and Caicos Islands                         12
# Somalia                                          10
# Djibouti                                         10
#
# [242 rows x 1 columns]

# %%
year_count = year_count.sort_values(by = 'count', ascending = True)

# %%
year_count.head(40)
# Out:
#                            count
# Country
# Djibouti                      10
# Somalia                       10
# Turks and Caicos Islands      12
# Sint Maarten (Dutch part)     14
# Kosovo                        15
# Cayman Islands                16
# Nauru                         19
# Afghanistan                   20
# Ṣo Tom̩ and Principe       22
# Cura̤ao                      22
# Palau                         22
# Qatar                         23
# Other small states            23
# Liberia                       23
# Timor-Leste                   23
# Libya                         24
# San Marino                    25
# Small states                  26
# Montenegro                    26
# Slovenia                      28
# Croatia                       28
# Maldives                      28
# Moldova                       28
# Iceland                       28
# Lithuania                     28
# Serbia                        28
# Estonia                       28
# ...

# %%
year_count.shape
# Out:
# (242, 1)

# %% [markdown]
# 202 countries have data for all 33 years. 40 countries are missing some years of data. Djibouti, Somalia, and Turks and Caicos are the top three countries missing the most amount of years having 10, 10, and 12 respectively. It seems that the most amount of missing data are the years in the early 90s.

# %% [markdown]
# #8--------------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_20 = gdp_df.loc[gdp_df.Year == 2020]
gdp_20
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %%
sns.histplot(data = gdp_20['GDP_Per_Capita']);
# Out:
# C:\Users\jbreu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.kdeplot(data = gdp_20['GDP_Per_Capita']);
# Out:
# C:\Users\jbreu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(y = gdp_20['GDP_Per_Capita']);

# %%
sns.violinplot(y = gdp_20['GDP_Per_Capita']);

# %% [markdown]
# #9------------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_20.GDP_Per_Capita.median()
# Out:
# 13357.997573370474

# %% [markdown]
# The median GDP Per Capita in 2020 was $13358.

# %% [markdown]
# #10-----------------------------------------------------------------------------------------------------------------------------------------

# %%
years = [1990, 2000, 2010, 2020]
gdp_decades = gdp_df.loc[gdp_df.Year.isin(years)]
gdp_decades
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 11                    Afghanistan  2010     2026.163818
# 22    Africa Eastern and Southern  2020     3455.023119
# 32    Africa Eastern and Southern  2010     3513.315920
# 42    Africa Eastern and Southern  2000     2897.140841
# ...                           ...   ...             ...
# 7628                       Zambia  1990     2290.039226
# 7631                     Zimbabwe  2020     1990.319419
# 7641                     Zimbabwe  2010     1799.540233
# 7651                     Zimbabwe  2000     2750.601236
# 7661                     Zimbabwe  1990     2704.757299
#
# [921 rows x 3 columns]

# %%
sns.boxplot(x = gdp_decades.Year, y = gdp_decades.GDP_Per_Capita);

# %%
sns.barplot(x = 'Year',
            y = 'GDP_Per_Capita',
            data = gdp_decades);

# %%
sns.regplot(x = gdp_decades.Year,
            y = gdp_decades.GDP_Per_Capita,
           fit_reg = False);

# %%
sns.regplot(x = gdp_decades.Year,
            y = gdp_decades.GDP_Per_Capita,
            line_kws = {
                "color": "g",
                "alpha": 0.5});

# %% [markdown]
# GDP Per Capita seems to be steadily increasing as the years progress. I believe that the scatter plot provides the most information especially with the overlayed trend line. The box and bar chart are easy to read but dont provide a detailed visualizaiton of the information.

# %% [markdown]
# #11--------------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_100 = gdp_df.loc[gdp_df.GDP_Per_Capita > 100000]
gdp_100
# Out:
#                    Country  Year  GDP_Per_Capita
# 3277               Ireland  2022   113870.785550
# 3278               Ireland  2021   102785.490239
# 4146            Luxembourg  2022   115541.774828
# 4147            Luxembourg  2021   115683.493708
# 4148            Luxembourg  2020   111751.314751
# 4149            Luxembourg  2019   114542.496934
# 4150            Luxembourg  2018   114164.468558
# 4151            Luxembourg  2017   114985.842236
# 4152            Luxembourg  2016   116283.699681
# 4153            Luxembourg  2015   113182.728563
# 4154            Luxembourg  2014   113313.578898
# 4155            Luxembourg  2013   113050.663254
# 4156            Luxembourg  2012   112137.135491
# 4157            Luxembourg  2011   112998.390477
# 4158            Luxembourg  2010   114343.988089
# 4159            Luxembourg  2009   112230.081410
# 4160            Luxembourg  2008   118154.667184
# 4161            Luxembourg  2007   120647.822959
# ...

# %%
gdp_100.sort_values(by = 'Year', ascending = True).head()
# Out:
#                    Country  Year  GDP_Per_Capita
# 7302  United Arab Emirates  1990   105893.626059
# 7301  United Arab Emirates  1991   101048.696239
# 7295  United Arab Emirates  1997   100956.706467
# 4167            Luxembourg  2001   101143.147977
# 4166            Luxembourg  2002   103317.331098

# %% [markdown]
# The first country to reach a GDP Per Capita over 100,000 was the UAE.

# %% [markdown]
# #12----------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_20.sort_values(by = 'GDP_Per_Capita', ascending = False)
# Out:
#                        Country  Year  GDP_Per_Capita
# 4148                Luxembourg  2020   111751.314751
# 6108                 Singapore  2020    94910.101431
# 3279                   Ireland  2020    91356.855054
# 5746                     Qatar  2020    89019.069857
# 681                    Bermuda  2020    76117.804744
# ...                        ...   ...             ...
# 5074                     Niger  2020     1214.546556
# 6273                   Somalia  2020     1127.418534
# 1630           Dem. Rep. Congo  2020     1044.071214
# 1217  Central African Republic  2020      847.765012
# 973                    Burundi  2020      711.355263
#
# [242 rows x 3 columns]

# %% [markdown]
# Luxembourg had the highest GDP Per Capita in 2020 at $111,751.

# %%
gdp_luxembourg = gdp_df.loc[gdp_df.Country == 'Luxembourg']
gdp_luxembourg
# Out:
#          Country  Year  GDP_Per_Capita
# 4146  Luxembourg  2022   115541.774828
# 4147  Luxembourg  2021   115683.493708
# 4148  Luxembourg  2020   111751.314751
# 4149  Luxembourg  2019   114542.496934
# 4150  Luxembourg  2018   114164.468558
# 4151  Luxembourg  2017   114985.842236
# 4152  Luxembourg  2016   116283.699681
# 4153  Luxembourg  2015   113182.728563
# 4154  Luxembourg  2014   113313.578898
# 4155  Luxembourg  2013   113050.663254
# 4156  Luxembourg  2012   112137.135491
# 4157  Luxembourg  2011   112998.390477
# 4158  Luxembourg  2010   114343.988089
# 4159  Luxembourg  2009   112230.081410
# 4160  Luxembourg  2008   118154.667184
# 4161  Luxembourg  2007   120647.822959
# 4162  Luxembourg  2006   113346.035782
# 4163  Luxembourg  2005   108632.360016
# 4164  Luxembourg  2004   107634.837198
# 4165  Luxembourg  2003   104743.000088
# 4166  Luxembourg  2002   103317.331098
# 4167  Luxembourg  2001   101143.147977
# 4168  Luxembourg  2000    99301.526999
# ...

# %%
plt.plot('Year', 'GDP_Per_Capita', data = gdp_luxembourg)
plt.xlabel('Year')
plt.ylabel('GDP Per Capita')
plt.title('Luxembourg GDP Per Capita Over Time');

# %% [markdown]
# #13------------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_20.sort_values(by = 'GDP_Per_Capita', ascending = True)
# Out:
#                        Country  Year  GDP_Per_Capita
# 973                    Burundi  2020      711.355263
# 1217  Central African Republic  2020      847.765012
# 1630           Dem. Rep. Congo  2020     1044.071214
# 6273                   Somalia  2020     1127.418534
# 5074                     Niger  2020     1214.546556
# ...                        ...   ...             ...
# 681                    Bermuda  2020    76117.804744
# 5746                     Qatar  2020    89019.069857
# 3279                   Ireland  2020    91356.855054
# 6108                 Singapore  2020    94910.101431
# 4148                Luxembourg  2020   111751.314751
#
# [242 rows x 3 columns]

# %%
gdp_burundi = gdp_df.loc[gdp_df.Country == 'Burundi']
gdp_burundi
# Out:
#       Country  Year  GDP_Per_Capita
# 971   Burundi  2022      708.178317
# 972   Burundi  2021      714.066712
# 973   Burundi  2020      711.355263
# 974   Burundi  2019      729.658463
# 975   Burundi  2018      740.448223
# 976   Burundi  2017      750.787616
# 977   Burundi  2016      764.336602
# 978   Burundi  2015      781.579287
# 979   Burundi  2014      831.294839
# 980   Burundi  2013      824.610523
# 981   Burundi  2012      814.320771
# 982   Burundi  2011      807.664958
# 983   Burundi  2010      804.354941
# 984   Burundi  2009      801.803427
# 985   Burundi  2008      812.592170
# 986   Burundi  2007      807.447481
# 987   Burundi  2006      809.696011
# 988   Burundi  2005      796.108713
# 989   Burundi  2004      818.746063
# 990   Burundi  2003      810.552335
# 991   Burundi  2002      846.747295
# 992   Burundi  2001      833.670879
# 993   Burundi  2000      837.348411
# 994   Burundi  1999      862.006680
# 995   Burundi  1998      891.699844
# ...

# %%
plt.plot('Year', 'GDP_Per_Capita', data = gdp_burundi)
plt.xlabel('Year')
plt.ylabel('GDP Per Capita')
plt.title('Burundi GDP Per Capita Over Time');

# %%
#13 Bonus-------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_90 = gdp_df.loc[gdp_df.Year == 1990]

# %%
gdp_20_and_90 = pd.merge(gdp_20, gdp_90,
                         left_on = 'Country', right_on = 'Country',
                         how = 'inner')

# %%
gdp_20_and_90['gdp_diff'] = gdp_20_and_90.GDP_Per_Capita_x - gdp_20_and_90.GDP_Per_Capita_y

# %%
gdp_20_and_90_lower = gdp_20_and_90.loc[gdp_20_and_90.gdp_diff < 0]

# %%
gdp_20_and_90_lower
# Out:
#                                       Country  Year_x  GDP_Per_Capita_x  \
# 15                                   Barbados    2020      13805.777541
# 25                                     Brunei    2020      61603.550804
# 28                                    Burundi    2020        711.355263
# 34                   Central African Republic    2020        847.765012
# 41                                      Congo    2020       3384.654335
# 45                            Dem. Rep. Congo    2020       1044.071214
# 66   Fragile and conflict affected situations    2020       4357.621312
# 68                                      Gabon    2020      13903.288955
# 76                              Guinea-Bissau    2020       1803.630591
# 78                                      Haiti    2020       2970.462845
# 99                                   Kiribati    2020       1897.061922
# 101                           Kyrgyz Republic    2020       4726.196559
# ...

# %%
gdp_20_and_90_lower.sort_values(by = 'gdp_diff', ascending = True)
# Out:
#                                       Country  Year_x  GDP_Per_Capita_x  \
# 196                      United Arab Emirates    2020      67668.286641
# 186                               The Bahamas    2020      25780.414176
# 25                                     Brunei    2020      61603.550804
# 195                                   Ukraine    2020      12407.790039
# 68                                      Gabon    2020      13903.288955
# 41                                      Congo    2020       3384.654335
# 206                                  Zimbabwe    2020       1990.319419
# 45                            Dem. Rep. Congo    2020       1044.071214
# 78                                      Haiti    2020       2970.462845
# 66   Fragile and conflict affected situations    2020       4357.621312
# 28                                    Burundi    2020        711.355263
# 101                           Kyrgyz Republic    2020       4726.196559
# ...

# %% [markdown]
# There are 19 countries that had a lower GDP Per Capita in 2020 than in 1990 with the three highest differences coming from the UAE, The Bahamas, and Brunei.

# %% [markdown]
# #14------------------------------------------------------------------------------------------------------------------------------------------

# %%
internet_df = pd.read_csv('../data/internet_use.csv', nrows = 6083)
internet_df.head()
# Out:
#   Country or Area  Year  Value Value Footnotes
# 0     Afghanistan  2019  17.60               1
# 1     Afghanistan  2018  16.80               2
# 2     Afghanistan  2017  13.50               3
# 3     Afghanistan  2016  11.00               4
# 4     Afghanistan  2015   8.26               4

# %%
internet_df.tail()
# Out:
#      Country or Area  Year     Value Value Footnotes
# 6078        Zimbabwe  1997  0.033080             NaN
# 6079        Zimbabwe  1996  0.016790             NaN
# 6080        Zimbabwe  1995  0.007684             NaN
# 6081        Zimbabwe  1994  0.001739             NaN
# 6082        Zimbabwe  1990  0.000000             NaN

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  6083 non-null   object
#  1   Year             6083 non-null   int64
#  2   Value            6083 non-null   float64
#  3   Value Footnotes  2826 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 190.2+ KB

# %% [markdown]
# I was able to remove the rows at the bottom of the DF with the nroms function. Country or Area is an object, Year is an object, Value is a float, and Value Footnotes is an object.

# %% [markdown]
# #15------------------------------------------------------------------------------------------------------------------------------------------

# %%
internet_df = internet_df.drop(columns = 'Value Footnotes')

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']

# %%
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2019           17.600000
# 1     Afghanistan  2018           16.800000
# 2     Afghanistan  2017           13.500000
# 3     Afghanistan  2016           11.000000
# 4     Afghanistan  2015            8.260000
# ...           ...   ...                 ...
# 6078     Zimbabwe  1997            0.033080
# 6079     Zimbabwe  1996            0.016790
# 6080     Zimbabwe  1995            0.007684
# 6081     Zimbabwe  1994            0.001739
# 6082     Zimbabwe  1990            0.000000
#
# [6083 rows x 3 columns]

# %% [markdown]
# #16-------------------------------------------------------------------------------------------------------------------------------------------

# %%
internet_df.Year.value_counts()
# Out:
# Year
# 1990    226
# 2007    217
# 2011    214
# 2008    214
# 2009    214
# 2002    214
# 2006    212
# 2001    212
# 2005    212
# 2004    210
# 2000    210
# 2010    209
# 2012    209
# 2003    208
# 1999    207
# 2016    206
# 2017    205
# 2014    204
# 2015    203
# 2013    203
# 1998    195
# 1997    188
# 2021    186
# 2020    186
# 2019    185
# 2022    184
# 1996    177
# 2018    174
# 1995    141
# 1994     92
# 1993     66
# 1992     50
# 1991     39
# 2023     11
# Name: count, dtype: int64

# %% [markdown]
# It seems that the distribution of values for years does not follow any particular trend and is pretty random throughout the years.

# %% [markdown]
# #17---------------------------------------------------------------------------------------------------------------------------------------------

# %%
internet_abv_zero = internet_df.loc[internet_df.Internet_Users_Pct > 0]
internet_abv_zero.sort_values(by = 'Year', ascending = True)
# Out:
#                      Country  Year  Internet_Users_Pct
# 1570                 Denmark  1990            0.097277
# 2892                   Japan  1990            0.020294
# 306                Australia  1990            0.585095
# 2034                  France  1990            0.052778
# 339                  Austria  1990            0.130369
# ...                      ...   ...                 ...
# 427               Bangladesh  2023           44.502700
# 677   Bosnia and Herzegovina  2023           83.377200
# 1656                 Ecuador  2023           72.694300
# 1537                 Denmark  2023           98.775600
# 3057                  Kuwait  2023           99.747300
#
# [5803 rows x 3 columns]

# %% [markdown]
# It looks like 1990 was the first year with many countries reaching an internet users percentage that was non zero.

# %% [markdown]
# #18--------------------------------------------------------------------------------------------------------------------------------------------

# %%
internet_list = [2000, 2014]
internet_00_14 = internet_df.loc[internet_df.Year.isin(internet_list)]
internet_00_14
# Out:
#           Country  Year  Internet_Users_Pct
# 5     Afghanistan  2014            7.000000
# 28        Albania  2014           54.300000
# 42        Albania  2000            0.114097
# 57        Algeria  2014           29.500000
# 71        Algeria  2000            0.491706
# ...           ...   ...                 ...
# 6017        Yemen  2000            0.082500
# 6031       Zambia  2014            6.500000
# 6045       Zambia  2000            0.191072
# 6061     Zimbabwe  2014           16.364700
# 6075     Zimbabwe  2000            0.401434
#
# [414 rows x 3 columns]

# %%
sns.boxplot(x = internet_00_14.Year, y = internet_00_14.Internet_Users_Pct)
# Out:
# <Axes: xlabel='Year', ylabel='Internet_Users_Pct'>

# %% [markdown]
# The distribution of internet users percentage was much hiher in 2014 than in 2000.

# %% [markdown]
# #19---------------------------------------------------------------------------------------------------------------------------------------------

# %%
internet_14 = internet_df.loc[internet_df.Year == 2014]

# %%
internet_14 = internet_14.loc[internet_14.Internet_Users_Pct < 5]

# %%
internet_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 873 to 5116
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             10 non-null     object
#  1   Year                10 non-null     int64
#  2   Internet_Users_Pct  10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 320.0+ bytes

# %% [markdown]
# There are 10 countries that have a internet users percentage below 5 in 2014.

# %% [markdown]
# #20---------------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df,
                                left_on = ['Country', 'Year'], right_on = ['Country', 'Year'],
                                how = 'outer')
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2021     1517.016266                 NaN
# 1     Afghanistan  2020     1968.341002                 NaN
# 2     Afghanistan  2019     2079.921861           17.600000
# 3     Afghanistan  2018     2060.698973           16.800000
# 4     Afghanistan  2017     2096.093111           13.500000
# ...           ...   ...             ...                 ...
# 9107        Yemen  1999             NaN            0.056629
# 9108        Yemen  1998             NaN            0.023323
# 9109        Yemen  1997             NaN            0.015025
# 9110        Yemen  1996             NaN            0.000621
# 9111        Yemen  1990             NaN            0.000000
#
# [9112 rows x 4 columns]

# %% [markdown]
# #21 + #22-----------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use.loc[gdp_and_internet_use.Year == 2014]

# %%
top_3 = gdp_and_internet_use_2014.sort_values(by = 'Internet_Users_Pct', ascending = False).head(3)

# %%
top_3
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2993                      Iceland  2014    50450.741612              98.158
# 8131  Falkland (Malvinas) Islands  2014             NaN              97.600
# 687                       Bermuda  2014    77361.104881              96.800

# %% [markdown]
# The three countries with the highest internet users percentage in 2014 are Iceland, Falkland (Malvinas) Islands, and Bermuda.

# %%
countries = top_3.Country.to_list()

# %%
top_3_total = gdp_df.loc[gdp_df.Country.isin(countries)]

# %%
f = sns.FacetGrid(top_3_total, col = 'Country')
f.map(sns.lineplot, 'Year', 'GDP_Per_Capita');
# Out:
# C:\Users\jbreu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jbreu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jbreu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# There was no GDP data for the Falkland Islands but it looks like the GDP Per Capita for Bermuda and Iceland are trending upwards with Bermuda experiencing a dip around 2008. Bermudas GDP Per Capita remains above Icelands throughout all the data.

# %% [markdown]
# #23--------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.scatterplot(x = gdp_and_internet_use_2014.Internet_Users_Pct, y = gdp_and_internet_use_2014.GDP_Per_Capita)
# Out:
# <Axes: xlabel='Internet_Users_Pct', ylabel='GDP_Per_Capita'>

# %% [markdown]
# There is a clear positive corolation between GDP Per Capita and Internet Use for countries in 2014. There are a few outliers that will be investigated below.

# %%
a = gdp_and_internet_use_2014.loc[gdp_and_internet_use.Internet_Users_Pct < 20]
a = a.loc[a.GDP_Per_Capita > 20000]
a
# Out:
#                 Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2009  Equatorial Guinea  2014    28106.198389               18.86

# %% [markdown]
# Equatorial Guinea was the first outlier that I saw that had a high GDP Per Capita of 28k with a fairly low Internet Users Pct of 18.

# %%
b = gdp_and_internet_use_2014.loc[gdp_and_internet_use.Internet_Users_Pct < 90]
b = b.loc[b.GDP_Per_Capita > 80000]
b
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6114  Singapore  2014    87702.521984             79.0292

# %% [markdown]
# Singapore was another country I saw that stood out for having a very high GDP Per Capita at 87k while only having an Internet Users Pct of 79.

# %% [markdown]
# #24----------------------------------------------------------------------------------------------------------------------------------------------

# %%
gdp_2014 = gdp_df.loc[gdp_df.Year == 2014]

# %%
group = pd.qcut(gdp_2014.GDP_Per_Capita, 3, labels = ["Low", "Medium", "High"])

# %%
group
# Out:
# 7          Low
# 28         Low
# 61         Low
# 94      Medium
# 127     Medium
#          ...
# 7509    Medium
# 7542       Low
# 7571    Medium
# 7604       Low
# 7637       Low
# Name: GDP_Per_Capita, Length: 242, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
gdp_2014['GDP Group'] = group
# Out:
# C:\Users\jbreu\AppData\Local\Temp\ipykernel_16688\844391026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_2014['GDP Group'] = group

# %%
gdp_2014
# Out:
#                           Country  Year  GDP_Per_Capita GDP Group
# 7                     Afghanistan  2014     2144.449634       Low
# 28    Africa Eastern and Southern  2014     3642.875373       Low
# 61     Africa Western and Central  2014     4146.994622       Low
# 94                        Albania  2014    11586.817446    Medium
# 127                       Algeria  2014    11561.259795    Medium
# ...                           ...   ...             ...       ...
# 7509                     Viet Nam  2014     7641.909252    Medium
# 7542           West Bank and Gaza  2014     5967.073437       Low
# 7571                        World  2014    15120.730322    Medium
# 7604                       Zambia  2014     3375.941270       Low
# 7637                     Zimbabwe  2014     2316.954536       Low
#
# [242 rows x 4 columns]

# %% [markdown]
# #25---------------------------------------------------------------------------------------------------------------------------------------------

# %%
group_2014 = pd.qcut(gdp_and_internet_use_2014.GDP_Per_Capita, 3, labels = ["Low", "Medium", "High"])

# %%
gdp_and_internet_use_2014['GDP Group'] = group_2014
# Out:
# C:\Users\jbreu\AppData\Local\Temp\ipykernel_16688\1560649361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_and_internet_use_2014['GDP Group'] = group_2014

# %%
low = gdp_and_internet_use_2014.loc[gdp_and_internet_use_2014['GDP Group'] == "Low"]

# %%
medium = gdp_and_internet_use_2014.loc[gdp_and_internet_use_2014['GDP Group'] == "Medium"]

# %%
high = gdp_and_internet_use_2014.loc[gdp_and_internet_use_2014['GDP Group'] == "High"]

# %%
low.Internet_Users_Pct.median
# Out:
# <bound method Series.median of 7        7.0000
# 28          NaN
# 61          NaN
# 489     11.9000
# 654      6.0000
#          ...
# 7443    35.5000
# 7476    18.8000
# 7542        NaN
# 7604     6.5000
# 7637    16.3647
# Name: Internet_Users_Pct, Length: 81, dtype: float64>

# %%
medium.Internet_Users_Pct.median
# Out:
# <bound method Series.median of 94      54.3000
# 127     29.5000
# 160     21.3623
# 193     67.7800
# 226         NaN
#          ...
# 7134    12.2000
# 7245    46.2360
# 7377        NaN
# 7509    41.0000
# 7571        NaN
# Name: Internet_Users_Pct, Length: 80, dtype: float64>

# %%
high.Internet_Users_Pct.median
# Out:
# <bound method Series.median of 259     64.7000
# 324     83.7800
# 357     84.0000
# 390     80.9958
# 456     90.5031
#          ...
# 7167        NaN
# 7278    90.4000
# 7311    91.6133
# 7344    73.0000
# 7410    61.4625
# Name: Internet_Users_Pct, Length: 81, dtype: float64>

# %% [markdown]
# The median internet users pct for low, medium, and high gdp groups are 7, 54.3, and 64.7 respectively. The median of 7 for the low group was partiuclarly lower than the other two groups. While the high gdp group still had a higher median than the medium group, they are much closer together than the low gdp group median.
